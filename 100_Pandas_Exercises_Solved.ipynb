# %% [markdown]
# # 100 Pandas Exercises
#
# This is a collection of 100 pandas exercises ranging from basic data creation to advanced multi-index manipulation.
#
# **Difficulty Key:**
# * (★☆☆) Basic: Foundations and Series
# * (★★☆) Medium: Data Cleaning and Grouping
# * (★★★) Advanced: Complex Analysis and Optimization

# %%
import pandas as pd
import numpy as np
print(f"Pandas version: {pd.__version__}")

# %% [markdown]
# #### 1. Create an empty dataframe (★☆☆)

# %%
df = pd.DataFrame()

# %% [markdown]
# #### 2. Create a Series from a list [1, 7, 2] (★☆☆)

# %%
s = pd.Series([1, 7, 2])

# %% [markdown]
# #### 3. Create a DataFrame from a dictionary of lists (★☆☆)

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(data)

# %% [markdown]
# #### 4. How to get the documentation of the pandas 'merge' function? (★☆☆)

# %%
help(pd.merge)
# or
# pd.merge?

# %% [markdown]
# #### 5. Create a 5x5 dataframe with random values (★☆☆)

# %%
df = pd.DataFrame(np.random.rand(5, 5))

# %% [markdown]
# #### 6. Display the first 10 rows of a dataframe (★☆☆)

# %%
df.head(10)

# %% [markdown]
# #### 7. Find the number of rows and columns in a dataframe (★☆☆)

# %%
df.shape

# %% [markdown]
# #### 8. Select a single column by its name (★☆☆)

# %%
df['column_name']
# or
# df.column_name

# %% [markdown]
# #### 9. Select multiple columns by their names (★☆☆)

# %%
df[['col1', 'col2', 'col3']]

# %% [markdown]
# #### 10. Filter rows based on a single condition (★☆☆)

# %%
df[df['column'] > value]

# %% [markdown]
# #### 11. Select rows using multiple conditions (AND) (★☆☆)

# %%
dates = pd.date_range('2023-01-01', periods=10, freq='D')

# %% [markdown]
# #### 12. Select rows using multiple conditions (OR) (★☆☆)

# %%
df.set_index('column_name', inplace=True)

# %% [markdown]
# #### 13. Select rows where a value is in a list (isin) (★☆☆)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### 14. Rename a specific column (★☆☆)

# %%
df.rename(columns={'old_name': 'new_name'}, inplace=True)

# %% [markdown]
# #### 15. Drop a column from a dataframe (★☆☆)

# %%
df.drop(['col1', 'col2'], axis=1, inplace=True)

# %% [markdown]
# #### 16. Add a new column calculated from existing columns (★☆☆)

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### 17. Find the unique values in a column (★☆☆)

# %%
df.fillna(value=0, inplace=True)

# %% [markdown]
# #### 18. Count occurrences of each unique value in a column (★☆☆)

# %%
df.sort_values(by='column_name', ascending=True)

# %% [markdown]
# #### 19. Sort a dataframe by a column in ascending order (★☆☆)

# %%
df.groupby('column').sum()

# %% [markdown]
# #### 20. Sort a dataframe by multiple columns (★☆☆)

# %%
df['new_col'] = df['col'].apply(lambda x: x * 2)

# %% [markdown]
# #### 21. Use .iloc to select the first 3 rows and 2 columns (★☆☆)

# %%
result = pd.concat([df1, df2], axis=0)

# %% [markdown]
# #### 22. Use .loc to select rows by index labels (★☆☆)

# %%
result = pd.merge(df1, df2, on='key', how='inner')

# %% [markdown]
# #### 23. Find the mean of a numeric column (★☆☆)

# %%
pivot = pd.pivot_table(df, values='value', index='row', columns='col')

# %% [markdown]
# #### 24. Find the maximum value in each column (★☆☆)

# %%
unique_vals = df['column'].unique()

# %% [markdown]
# #### 25. Check for null values in a dataframe (★☆☆)

# %%
counts = df['column'].value_counts()

# %% [markdown]
# #### 26. Replace null values with a specific value (★☆☆)

# %%
duplicates = df.duplicated()

# %% [markdown]
# #### 27. Drop rows with any null values (★☆☆)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### 28. Drop duplicate rows (★☆☆)

# %%
correlation = df.corr()

# %% [markdown]
# #### 29. Change the data type of a column (★☆☆)

# %%
mean_val = df['column'].mean()

# %% [markdown]
# #### 30. Set a column as the dataframe index (★☆☆)

# %%
median_val = df['column'].median()

# %% [markdown]
# #### 31. Reset the index of a dataframe (★☆☆)

# %%
std_val = df['column'].std()

# %% [markdown]
# #### 32. Select the row with the maximum value in a column (★☆☆)

# %%
var_val = df['column'].var()

# %% [markdown]
# #### 33. Select rows based on a string prefix in a column (★☆☆)

# %%
min_val = df['column'].min()

# %% [markdown]
# #### 34. Convert a column of strings to lowercase (★☆☆)

# %%
max_val = df['column'].max()

# %% [markdown]
# #### 35. Group data by a column and calculate the sum (★★☆)

# %%
sum_val = df['column'].sum()

# %% [markdown]
# #### 36. Group data by multiple columns and find the mean (★★☆)

# %%
count = df['column'].count()

# %% [markdown]
# #### 37. Apply a custom function to a column using 'apply' (★★☆)

# %%
stats = df.describe()

# %% [markdown]
# #### 38. Use a lambda function with 'apply' (★★☆)

# %%
df.info()

# %% [markdown]
# #### 39. Concatenate two dataframes vertically (★★☆)

# %%
dtypes = df.dtypes

# %% [markdown]
# #### 40. Concatenate two dataframes horizontally (★★☆)

# %%
df['column'] = df['column'].astype('float')

# %% [markdown]
# #### 41. Merge two dataframes on a common column (Inner Join) (★★☆)

# %%
mask = df['column'] > threshold

# %% [markdown]
# #### 42. Perform a Left Join on two dataframes (★★☆)

# %%
filtered = df[(df['col1'] > 10) & (df['col2'] < 20)]

# %% [markdown]
# #### 43. Pivot a dataframe to long format using 'melt' (★★☆)

# %%
filtered = df[df['column'].isin(['value1', 'value2'])]

# %% [markdown]
# #### 44. Create a pivot table (★★☆)

# %%
filtered = df[df['column'].str.contains('pattern')]

# %% [markdown]
# #### 45. Find rows with any duplicate values across specific columns (★★☆)

# %%
df['column'] = df['column'].str.replace('old', 'new')

# %% [markdown]
# #### 46. Map values in a column using a dictionary (★★☆)

# %%
df[['col1', 'col2']] = df['column'].str.split('-', expand=True)

# %% [markdown]
# #### 47. Create a cross-tabulation table (crosstab) (★★☆)

# %%
df['column'] = df['column'].str.lower()

# %% [markdown]
# #### 48. Sample 5 random rows from a dataframe (★★☆)

# %%
df['column'] = df['column'].str.upper()

# %% [markdown]
# #### 49. Calculate the percentage change between rows (★★☆)

# %%
df['column'] = df['column'].str.strip()

# %% [markdown]
# #### 50. Calculate the correlation between two columns (★★☆)

# %%
df['year'] = df['date_column'].dt.year
df['month'] = df['date_column'].dt.month

# %% [markdown]
# #### 51. Extract the year from a datetime column (★★☆)

# %%
df['diff'] = df['date2'] - df['date1']

# %% [markdown]
# #### 52. Resample a time-series dataframe by month (★★☆)

# %%
resampled = df.resample('M').mean()

# %% [markdown]
# #### 53. Use 'query' to filter a dataframe (★★☆)

# %%
rolling_mean = df['column'].rolling(window=3).mean()

# %% [markdown]
# #### 54. Convert a dataframe to a dictionary (★★☆)

# %%
cumsum = df['column'].cumsum()

# %% [markdown]
# #### 55. Convert a dataframe to a NumPy array (★★☆)

# %%
cumprod = df['column'].cumprod()

# %% [markdown]
# #### 56. Fill missing values using forward-fill (ffill) (★★☆)

# %%
df['rank'] = df['column'].rank()

# %% [markdown]
# #### 57. Calculate the rolling mean of a column (★★☆)

# %%
pct_change = df['column'].pct_change()

# %% [markdown]
# #### 58. Replace specific strings in a column using regex (★★☆)

# %%
shifted = df['column'].shift(1)

# %% [markdown]
# #### 59. Calculate the rank of values in a column (★★☆)

# %%
df['column'] = df['column'].interpolate()

# %% [markdown]
# #### 60. Bin continuous data into categories using 'cut' (★★☆)

# %%
crosstab = pd.crosstab(df['col1'], df['col2'])

# %% [markdown]
# #### 61. Find the most frequent value in a column (★★☆)

# %%
arrays = [['A', 'A', 'B', 'B'], [1, 2, 1, 2]]
index = pd.MultiIndex.from_arrays(arrays, names=['first', 'second'])
df = pd.DataFrame(data, index=index)

# %% [markdown]
# #### 62. Normalize a numeric column (min-max scaling) (★★☆)

# %%
df.xs('A', level='first')

# %% [markdown]
# #### 63. Explode a column containing lists into multiple rows (★★☆)

# %%
stacked = df.stack()

# %% [markdown]
# #### 64. Check if two dataframes are equal (★★☆)

# %%
unstacked = df.unstack()

# %% [markdown]
# #### 65. Subtract the mean of each row from its elements (★★☆)

# %%
melted = pd.melt(df, id_vars=['id'], value_vars=['col1', 'col2'])

# %% [markdown]
# #### 66. Identify and drop rows where all columns are empty (★★☆)

# %%
pivoted = df.pivot(index='row', columns='col', values='value')

# %% [markdown]
# #### 67. Create a multi-index dataframe (★★★)

# %%
dummies = pd.get_dummies(df['category_column'])

# %% [markdown]
# #### 68. Select data from a multi-index dataframe using 'xs' (★★★)

# %%
df['column'] = df['column'].map({'old1': 'new1', 'old2': 'new2'})

# %% [markdown]
# #### 69. Calculate group-wise statistics using 'transform' (★★★)

# %%
df.replace({'old': 'new'}, inplace=True)

# %% [markdown]
# #### 70. Use 'pipe' to chain multiple operations (★★★)

# %%
result = df.query('column > 10 and other_col < 20')

# %% [markdown]
# #### 71. Perform a 'fuzzy' merge between two dataframes (★★★)

# %%
sample = df.sample(n=10)

# %% [markdown]
# #### 72. Flatten a multi-index column header (★★★)

# %%
sample = df.sample(frac=0.5)

# %% [markdown]
# #### 73. Calculate the cumulative sum of a column within groups (★★★)

# %%
top = df.nlargest(5, 'column')

# %% [markdown]
# #### 74. Convert categorical data to dummy variables (One-Hot Encoding) (★★★)

# %%
bottom = df.nsmallest(5, 'column')

# %% [markdown]
# #### 75. Identify outliers using the IQR method (★★★)

# %%
idx_max = df['column'].idxmax()

# %% [markdown]
# #### 76. Shift the index of a time-series by 2 days (★★★)

# %%
idx_min = df['column'].idxmin()

# %% [markdown]
# #### 77. Stack and Unstack a dataframe (★★★)

# %%
df['category'] = pd.cut(df['column'], bins=3, labels=['low', 'medium', 'high'])

# %% [markdown]
# #### 78. Efficiently iterate over rows using 'itertuples' (★★★)

# %%
df['quartile'] = pd.qcut(df['column'], q=4)

# %% [markdown]
# #### 79. Combine two columns into a single tuple-based column (★★★)

# %%
df['column'] = df['column'].clip(lower=0, upper=100)

# %% [markdown]
# #### 80. Select rows with the top 3 highest values in a group (★★★)

# %%
df['new_col'] = df['column'].where(df['column'] > 0, 0)

# %% [markdown]
# #### 81. Fill missing values with the group-wise mean (★★★)

# %%
df['new_col'] = df['column'].mask(df['column'] < 0, 0)

# %% [markdown]
# #### 82. Swap two levels of a multi-index (★★★)

# %%
filtered = df[df['column'].between(10, 20)]

# %% [markdown]
# #### 83. Calculate the expansion of a wide dataframe into a long one (melt) (★★★)

# %%
df = pd.read_csv('file.csv')

# %% [markdown]
# #### 84. Apply a function to groups and return a dataframe (★★★)

# %%
df.to_csv('output.csv', index=False)

# %% [markdown]
# #### 85. Check memory usage of each column (★★★)

# %%
df = pd.read_excel('file.xlsx', sheet_name='Sheet1')

# %% [markdown]
# #### 86. Read a CSV but only keep specific columns (★★★)

# %%
df.to_excel('output.xlsx', index=False)

# %% [markdown]
# #### 87. Use 'eval' for high-performance column operations (★★★)

# %%
df = pd.read_json('file.json')

# %% [markdown]
# #### 88. Mask values based on a complex condition (★★★)

# %%
df.to_json('output.json', orient='records')

# %% [markdown]
# #### 89. Find the intersection of two dataframes (★★★)

# %%
# Requires sqlalchemy
# df = pd.read_sql('SELECT * FROM table', connection)

# %% [markdown]
# #### 90. Create a custom index using 'from_product' (★★★)

# %%
# Requires sqlalchemy
# df.to_sql('table_name', connection, if_exists='replace')

# %% [markdown]
# #### 91. Convert a dataframe to HTML (★★★)

# %%
memory = df.memory_usage(deep=True)

# %% [markdown]
# #### 92. Identify rows with unequal values in a 10x3 matrix (★★★)

# %%
df['column'] = pd.to_numeric(df['column'], downcast='integer')

# %% [markdown]
# #### 93. Create a style highlight for the maximum value in a dataframe (★★★)

# %%
df['column'] = df['column'].astype('category')

# %% [markdown]
# #### 94. Implement a simple Game of Life using pandas? (★★★)

# %%
df = df.explode('list_column')

# %% [markdown]
# #### 95. Perform a cross-join between two small dataframes (★★★)

# %%
result = df.groupby('column').agg({'col1': ['sum', 'mean'], 'col2': 'max'})

# %% [markdown]
# #### 96. Select from X rows summing to 'n' (interpreted as draws) (★★★)

# %%
df['normalized'] = df.groupby('group')['value'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# #### 97. Extract contiguous 3x3 blocks from a 10x10 dataframe (★★★)

# %%
filtered = df.groupby('column').filter(lambda x: len(x) > 5)

# %% [markdown]
# #### 98. Build a cartesian product from multiple series (★★★)

# %%
expanding_mean = df['column'].expanding().mean()

# %% [markdown]
# #### 99. Compute bootstrapped 95% confidence intervals for a mean (★★★)

# %%
result = df.groupby('column').agg(lambda x: x.max() - x.min())

# %% [markdown]
# #### 100. Write a function to check for 'Data Leakage' across train/test splits (★★★)

# %%
result = (df
    .groupby('category')['value']
    .agg(['sum', 'mean', 'count'])
    .sort_values('sum', ascending=False)
    .head(10))
